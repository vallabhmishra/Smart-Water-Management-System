# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline
from matplotlib.pylab import rcParams
rcParams["figure.figsize"] = [6.4, 4.8]
from datetime import datetime

# %%
data = pd.read_csv(r"C:/Users/Piyus/Desktop/Review 2/austin_water_residential_water_consumption_1.csv")
data.shape
print(data)
# Out:
#        year_month  postal_code            customer_class  total_gallons
# 0          201403        78702               Residential       23450100
# 1          201311        78746              Multi-Family       12801400
# 2          201704        78652              Multi-Family          58400
# 3          201302        78727  Irrigation - Residential           1800
# 4          201608        78726  Irrigation - Residential          82200
# ...           ...          ...                       ...            ...
# 13035      201801        78730               Residential       16359100
# 13036      201807        78748               Residential       83211800
# 13037      201401        78724               Residential       21972100
# 13038      201609        78759               Residential       76283600
# 13039      201609        78702              Multi-Family       11815500
#
# [13040 rows x 4 columns]

# %%
data.style.hide_index()
data.head()
# Out:
#    year_month  postal_code            customer_class  total_gallons
# 0      201403        78702               Residential       23450100
# 1      201311        78746              Multi-Family       12801400
# 2      201704        78652              Multi-Family          58400
# 3      201302        78727  Irrigation - Residential           1800
# 4      201608        78726  Irrigation - Residential          82200

# %%
def timedate(x):
  x = str(x)
  x = x[0:4]+ str('-') + x[4:]+ str('-') + str('01')
  return x

data['year_month'] = data['year_month'].apply(lambda x: timedate(x))
data.head()
# Out:
#    year_month  postal_code            customer_class  total_gallons
# 0  2014-03-01        78702               Residential       23450100
# 1  2013-11-01        78746              Multi-Family       12801400
# 2  2017-04-01        78652              Multi-Family          58400
# 3  2013-02-01        78727  Irrigation - Residential           1800
# 4  2016-08-01        78726  Irrigation - Residential          82200

# %%
data['customer_class'].value_counts()
# Out:
# Residential                  3773
# Multi-Family                 3402
# Irrigation - Multi-Family    3024
# Irrigation - Residential     2841
# Name: customer_class, dtype: int64

# %%
Residential = data[data["customer_class"] == "Residential"]

# %%
d_res = Residential.copy(deep = True)

# %%
d_res.head()
# Out:
#     year_month  postal_code customer_class  total_gallons
# 0   2014-03-01        78702    Residential       23450100
# 7   2013-12-01        78719    Residential        1394200
# 9   2014-02-01        78753    Residential       33497500
# 20  2013-06-01        78732    Residential           6700
# 26  2013-01-01        78749    Residential       59260300

# %%
d_res = d_res.drop(['postal_code', 'customer_class'], axis = 1)

# %%
d_res.style.hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_99e8d967_7eaf_11eb_87d9_ac12030148a1" ><thead>    <tr>        <th class="col_heading level0 col0" >year_month</th>        <th class="col_heading level0 col1" >total_gallons</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_99e8d967_7eaf_11eb_87d9_ac12030148a1row0_col0" class="data row0 col0" >2014-03-01</td>
#                         <td id="T_99e8d967_7eaf_11eb_87d9_ac12030148a1row0_col1" class="data row0 col1" >23450100</td>
#             </tr>
#             <tr>
#                                 <td id="T_99e8d967_7eaf_11eb_87d9_ac12030148a1row1_col0" class="data row1 col0" >2013-12-01</td>
#                         <td id="T_99e8d967_7eaf_11eb_87d9_ac12030148a1row1_col1" class="data row1 col1" >1394200</td>
#             </tr>
#             <tr>
#                                 <td id="T_99e8d967_7eaf_11eb_87d9_ac12030148a1row2_col0" class="data row2 col0" >2014-02-01</td>
# ...

# %%
d_res.to_csv(r'C:/Users/Piyus/Desktop/Review 2/residential_dataset.csv', index = False)
